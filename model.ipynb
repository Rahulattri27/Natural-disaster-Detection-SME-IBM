# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
train_dataset_path = '/Users/rahulkumarair/Documents/rahul_vsCode/Natural_disaster/natural2_disaster/dataset2/train'
validation_dataset_path = '/Users/rahulkumarair/Documents/rahul_vsCode/Natural_disaster/natural2_disaster/dataset2/val'

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 482 images belonging to 4 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 137 images belonging to 4 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Flood
# 1 : cyclone
# 2 : earthquake
# 3 : wildire

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
def create_model():
    model = Sequential([
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Flatten(),
        
        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=4, activation='softmax')
    ])
    
    return model

# %%
cnn_model = create_model()
print(cnn_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 146, 146, 128)     9728
#
#  activation (Activation)     (None, 146, 146, 128)     0
#
#  max_pooling2d (MaxPooling2  (None, 73, 73, 128)       0
#  D)
#
#  batch_normalization (Batch  (None, 73, 73, 128)       512
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 71, 71, 64)        73792
#
#  activation_1 (Activation)   (None, 71, 71, 64)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 35, 35, 64)        0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 35, 35, 64)        256
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 33, 33, 32)        18464
#
#  activation_2 (Activation)   (None, 33, 33, 32)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 16, 16, 32)        128
#  chNormalization)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 2201316 (8.40 MB)
# Trainable params: 2200868 (8.40 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# None

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %%
optimizer = Adam(learning_rate=0.001)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %%
cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %%
history = cnn_model.fit(train_generator, epochs=50, validation_data=validation_generator,
                       verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 16/16 - 32s - loss: 2.4290 - accuracy: 0.5000 - val_loss: 1.5842 - val_accuracy: 0.4964 - lr: 0.0010 - 32s/epoch - 2s/step
# Epoch 2/50
# 16/16 - 31s - loss: 2.4460 - accuracy: 0.5788 - val_loss: 1.7161 - val_accuracy: 0.3431 - lr: 0.0010 - 31s/epoch - 2s/step
# Epoch 3/50
# 16/16 - 30s - loss: 2.1096 - accuracy: 0.6390 - val_loss: 1.5511 - val_accuracy: 0.3431 - lr: 0.0010 - 30s/epoch - 2s/step
# Epoch 4/50
# 16/16 - 30s - loss: 1.8000 - accuracy: 0.6515 - val_loss: 1.5195 - val_accuracy: 0.3796 - lr: 0.0010 - 30s/epoch - 2s/step
# Epoch 5/50
# 16/16 - 32s - loss: 1.5236 - accuracy: 0.6743 - val_loss: 1.6083 - val_accuracy: 0.4234 - lr: 0.0010 - 32s/epoch - 2s/step
# Epoch 6/50
# 16/16 - 28s - loss: 1.7261 - accuracy: 0.6888 - val_loss: 1.2976 - val_accuracy: 0.4380 - lr: 0.0010 - 28s/epoch - 2s/step
# Epoch 7/50
# 16/16 - 28s - loss: 1.4531 - accuracy: 0.6515 - val_loss: 1.2136 - val_accuracy: 0.4088 - lr: 0.0010 - 28s/epoch - 2s/step
# Epoch 8/50
# 16/16 - 28s - loss: 1.4305 - accuracy: 0.6722 - val_loss: 1.3382 - val_accuracy: 0.4307 - lr: 0.0010 - 28s/epoch - 2s/step
# Epoch 9/50
# 16/16 - 28s - loss: 1.5925 - accuracy: 0.6473 - val_loss: 1.2266 - val_accuracy: 0.4526 - lr: 0.0010 - 28s/epoch - 2s/step
# Epoch 10/50
# 16/16 - 28s - loss: 1.2996 - accuracy: 0.6473 - val_loss: 1.1116 - val_accuracy: 0.5255 - lr: 0.0010 - 28s/epoch - 2s/step
# Epoch 11/50
# 16/16 - 32s - loss: 1.3181 - accuracy: 0.6743 - val_loss: 0.9944 - val_accuracy: 0.5839 - lr: 0.0010 - 32s/epoch - 2s/step
# Epoch 12/50
# 16/16 - 33s - loss: 1.4319 - accuracy: 0.6867 - val_loss: 1.1391 - val_accuracy: 0.5109 - lr: 0.0010 - 33s/epoch - 2s/step
# Epoch 13/50
# 16/16 - 29s - loss: 1.0778 - accuracy: 0.7365 - val_loss: 1.0570 - val_accuracy: 0.5839 - lr: 0.0010 - 29s/epoch - 2s/step
# Epoch 14/50
# 16/16 - 28s - loss: 0.9471 - accuracy: 0.7510 - val_loss: 1.3887 - val_accuracy: 0.3139 - lr: 0.0010 - 28s/epoch - 2s/step
# Epoch 15/50
# 16/16 - 28s - loss: 1.1044 - accuracy: 0.7261 - val_loss: 2.0485 - val_accuracy: 0.3139 - lr: 0.0010 - 28s/epoch - 2s/step
# Epoch 16/50
# 16/16 - 29s - loss: 1.1532 - accuracy: 0.7282 - val_loss: 2.1485 - val_accuracy: 0.3431 - lr: 0.0010 - 29s/epoch - 2s/step
# Epoch 17/50
# 16/16 - 30s - loss: 1.1070 - accuracy: 0.7427 - val_loss: 1.8741 - val_accuracy: 0.3358 - lr: 3.1623e-04 - 30s/epoch - 2s/step
# Epoch 18/50
# 16/16 - 28s - loss: 1.0542 - accuracy: 0.7759 - val_loss: 1.8743 - val_accuracy: 0.3577 - lr: 3.1623e-04 - 28s/epoch - 2s/step
# Epoch 19/50
# 16/16 - 29s - loss: 0.7171 - accuracy: 0.7842 - val_loss: 1.8468 - val_accuracy: 0.3504 - lr: 3.1623e-04 - 29s/epoch - 2s/step
# Epoch 20/50
# 16/16 - 30s - loss: 1.0943 - accuracy: 0.7386 - val_loss: 1.1582 - val_accuracy: 0.5255 - lr: 3.1623e-04 - 30s/epoch - 2s/step
# Epoch 21/50
# 16/16 - 28s - loss: 0.7948 - accuracy: 0.7718 - val_loss: 0.9964 - val_accuracy: 0.6058 - lr: 3.1623e-04 - 28s/epoch - 2s/step
# Epoch 22/50
# 16/16 - 28s - loss: 0.8439 - accuracy: 0.7718 - val_loss: 0.9940 - val_accuracy: 0.5985 - lr: 1.0000e-04 - 28s/epoch - 2s/step
# Epoch 23/50
# 16/16 - 28s - loss: 0.9107 - accuracy: 0.7552 - val_loss: 1.0289 - val_accuracy: 0.6204 - lr: 1.0000e-04 - 28s/epoch - 2s/step
# Epoch 24/50
# 16/16 - 28s - loss: 0.8338 - accuracy: 0.7448 - val_loss: 1.0593 - val_accuracy: 0.6277 - lr: 1.0000e-04 - 28s/epoch - 2s/step
# Epoch 25/50
# 16/16 - 29s - loss: 0.8708 - accuracy: 0.7407 - val_loss: 0.8814 - val_accuracy: 0.7007 - lr: 1.0000e-04 - 29s/epoch - 2s/step
# Epoch 26/50
# 16/16 - 28s - loss: 0.8594 - accuracy: 0.7884 - val_loss: 0.8652 - val_accuracy: 0.7299 - lr: 1.0000e-04 - 28s/epoch - 2s/step
# Epoch 27/50
# 16/16 - 28s - loss: 0.6070 - accuracy: 0.8154 - val_loss: 0.8597 - val_accuracy: 0.7518 - lr: 1.0000e-04 - 28s/epoch - 2s/step
# Epoch 28/50
# 16/16 - 28s - loss: 0.4967 - accuracy: 0.8237 - val_loss: 0.8393 - val_accuracy: 0.7518 - lr: 1.0000e-04 - 28s/epoch - 2s/step
# Epoch 29/50
# 16/16 - 28s - loss: 0.5396 - accuracy: 0.8091 - val_loss: 0.8140 - val_accuracy: 0.7591 - lr: 1.0000e-04 - 28s/epoch - 2s/step
# Epoch 30/50
# 16/16 - 28s - loss: 0.5160 - accuracy: 0.8174 - val_loss: 0.8025 - val_accuracy: 0.7518 - lr: 1.0000e-04 - 28s/epoch - 2s/step
# Epoch 31/50
# 16/16 - 28s - loss: 0.6868 - accuracy: 0.8174 - val_loss: 0.8163 - val_accuracy: 0.7664 - lr: 1.0000e-04 - 28s/epoch - 2s/step
# Epoch 32/50
# 16/16 - 30s - loss: 0.6256 - accuracy: 0.8091 - val_loss: 0.8549 - val_accuracy: 0.7664 - lr: 1.0000e-04 - 30s/epoch - 2s/step
# Epoch 33/50
# 16/16 - 31s - loss: 0.5738 - accuracy: 0.8278 - val_loss: 0.8622 - val_accuracy: 0.7737 - lr: 1.0000e-04 - 31s/epoch - 2s/step
# Epoch 34/50
# 16/16 - 28s - loss: 0.5708 - accuracy: 0.8112 - val_loss: 0.8548 - val_accuracy: 0.7883 - lr: 1.0000e-04 - 28s/epoch - 2s/step
# Epoch 35/50
# 16/16 - 28s - loss: 0.4454 - accuracy: 0.8506 - val_loss: 0.8676 - val_accuracy: 0.7737 - lr: 1.0000e-04 - 28s/epoch - 2s/step
# Epoch 36/50
# 16/16 - 28s - loss: 0.5234 - accuracy: 0.8278 - val_loss: 0.8773 - val_accuracy: 0.7810 - lr: 3.1623e-05 - 28s/epoch - 2s/step
# Epoch 37/50
# 16/16 - 28s - loss: 0.5350 - accuracy: 0.8154 - val_loss: 0.8992 - val_accuracy: 0.7810 - lr: 3.1623e-05 - 28s/epoch - 2s/step
# Epoch 38/50
# 16/16 - 28s - loss: 0.6719 - accuracy: 0.8361 - val_loss: 0.9089 - val_accuracy: 0.7810 - lr: 3.1623e-05 - 28s/epoch - 2s/step
# Epoch 39/50
# 16/16 - 28s - loss: 0.4955 - accuracy: 0.8340 - val_loss: 0.8971 - val_accuracy: 0.7883 - lr: 3.1623e-05 - 28s/epoch - 2s/step
# Epoch 40/50
# 16/16 - 28s - loss: 0.4957 - accuracy: 0.8195 - val_loss: 0.9062 - val_accuracy: 0.8029 - lr: 3.1623e-05 - 28s/epoch - 2s/step
# Epoch 41/50
# 16/16 - 28s - loss: 0.4970 - accuracy: 0.8320 - val_loss: 0.9192 - val_accuracy: 0.8029 - lr: 1.0000e-05 - 28s/epoch - 2s/step
# Epoch 42/50
# 16/16 - 28s - loss: 0.7122 - accuracy: 0.8195 - val_loss: 0.9415 - val_accuracy: 0.8029 - lr: 1.0000e-05 - 28s/epoch - 2s/step
# Epoch 43/50
# 16/16 - 28s - loss: 0.5112 - accuracy: 0.8195 - val_loss: 0.9538 - val_accuracy: 0.8029 - lr: 1.0000e-05 - 28s/epoch - 2s/step
# Epoch 44/50
# 16/16 - 28s - loss: 0.6077 - accuracy: 0.8071 - val_loss: 0.9732 - val_accuracy: 0.7956 - lr: 1.0000e-05 - 28s/epoch - 2s/step
# Epoch 45/50
# 16/16 - 28s - loss: 0.5039 - accuracy: 0.8237 - val_loss: 0.9952 - val_accuracy: 0.7956 - lr: 1.0000e-05 - 28s/epoch - 2s/step
# Epoch 46/50
# 16/16 - 28s - loss: 0.5180 - accuracy: 0.8465 - val_loss: 1.0293 - val_accuracy: 0.7956 - lr: 3.1623e-06 - 28s/epoch - 2s/step
# Epoch 47/50
# 16/16 - 28s - loss: 0.5201 - accuracy: 0.8050 - val_loss: 1.0371 - val_accuracy: 0.7956 - lr: 3.1623e-06 - 28s/epoch - 2s/step
# Epoch 48/50
# 16/16 - 31s - loss: 0.5180 - accuracy: 0.8216 - val_loss: 1.0632 - val_accuracy: 0.7883 - lr: 3.1623e-06 - 31s/epoch - 2s/step
# Epoch 49/50
# 16/16 - 28s - loss: 0.6115 - accuracy: 0.8154 - val_loss: 1.0850 - val_accuracy: 0.7664 - lr: 3.1623e-06 - 28s/epoch - 2s/step
# Epoch 50/50
# 16/16 - 28s - loss: 0.5313 - accuracy: 0.8299 - val_loss: 1.1002 - val_accuracy: 0.7664 - lr: 3.1623e-06 - 28s/epoch - 2s/step

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
test_dataset = '/Users/rahulkumarair/Documents/rahul_vsCode/Natural_disaster/natural2_disaster/dataset2/test'
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 72 images belonging to 4 classes.

# %%
predictions = cnn_model.predict(test_generator)
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()
# Out:
# 3/3 [==============================] - 2s 605ms/step

# %%
test_loss, test_accuracy = cnn_model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 3/3 [==============================] - 2s 658ms/step - loss: 0.9902 - accuracy: 0.7639

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.9901845455169678
# Test Accuracy: 0.7638888955116272

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(4,4)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#        Flood       0.83      0.83      0.83        18
#      cyclone       0.74      0.70      0.72        20
#   earthquake       0.63      0.71      0.67        17
#      wildire       0.88      0.82      0.85        17
#
#     accuracy                           0.76        72
#    macro avg       0.77      0.77      0.77        72
# weighted avg       0.77      0.76      0.77        72

# %%
# Wrong Predictions

# Let's see where the model has given wrong predictions and what were the actual predictions on those images.

errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
